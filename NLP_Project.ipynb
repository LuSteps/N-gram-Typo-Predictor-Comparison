# %% [markdown]
# # Init

# %%
# !gdown 1s1WZkcd42vU-8hxHMtwVoYjeGD6_PQNA
# !gdown 1s5He5p-vl0HGt8qLPVNiplcE0g_vQ8iQ

import nltk
nltk.download('punkt')
nltk.download('reuters')
import pandas as pd
from nltk import ngrams, word_tokenize, Counter, edit_distance
from nltk.metrics.distance import edit_distance
from IPython.display import display
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s1WZkcd42vU-8hxHMtwVoYjeGD6_PQNA
# To: /content/test.txt
# 100% 3.20k/3.20k [00:00<00:00, 11.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1s5He5p-vl0HGt8qLPVNiplcE0g_vQ8iQ
# To: /content/answer.txt
# 100% 3.22k/3.22k [00:00<00:00, 13.1MB/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package reuters to /root/nltk_data...

# %% [markdown]
# # Edit Distance

# %%
# Kode dari artikel Peter Norvig: https://norvig.com/spell-correct.html
# Intinya generate semua string yang jaraknya distance tertentu dari word
# Pake yang namanya Damerau-Levenshtein distance.
# Ada transpose sebagai tambahan dari operasi lev biasa.
def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    "All edits that are two edits away from `word`."
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1))

# %% [markdown]
# # Model

# %%
# Bikin class biar rapih
class ngram_checker:
    # Kasih text training sama angka n_gram yang diinginkan.
    def __init__(self, text:int, n_gram:int):
        self.n_gram = n_gram
        self.word_freq = self._get_freq(text, n_gram)
        self.vocab = set(self.word_freq["word"].apply(lambda x: x[0]).unique())

    # Generate df ngram, dengan padding
    def _get_freq(self, text:str, n_gram:int):
        token = word_tokenize(text)
        grams = ngrams(token, n_gram, pad_left = True, pad_right = True, left_pad_symbol="<s>", right_pad_symbol="</s>")
        df = pd.DataFrame(Counter(grams).items(), columns=["word", "freq"])
        return df

    # Dari sebuah list of tokens dimana elemen terakhirnya typo,
    # buat daftar frekuensi huruf2 yang jaraknya 2 edit distance
    # aka token pengganti.
    def prob_grams(self, tokens:list[str]):
        ret = pd.DataFrame(columns=self.word_freq.columns)

        # Atur padding
        if len(tokens) < self.n_gram:
            tokens = (["<s>"] * (self.n_gram - len(tokens))) + tokens
        else:
            tokens = tokens[-self.n_gram:]

        # Ret kalo ada di vocab, bukan typo.
        word = tokens[-1]
        if word in self.vocab:
            return ret

        # Generate semua string yang mungkin buat edit distance 2, terus pilih yang dalam vocab kita.
        possible_edits = edits2(word)
        vocab_words = possible_edits.intersection(self.vocab)

        # filter dulu yang depannya sesuai, biar kodenya lebih cepet
        freq = self.word_freq[self.word_freq["word"].apply(lambda x: x[:-1] == tuple(tokens[:-1]))]

        # sekarang filter yang belakangnya sesuai
        for word in vocab_words:
            ret = pd.concat((ret, freq[freq["word"].apply(lambda x: x[-1] == word)]))

        return ret.sort_values("freq", ascending=False)

    # Fungsi yang bakal ngejalanin prob_grams secara otomatis.
    # Bakal nerima string habis itu secara otomatis tokenize.
    # Habis ditokenize diproses pake fungsi atas buat dapet list2 token pengganti.
    # Ambil token pengganti dengan probabilitas tertinggi, terus sambung.
    def autocorrect(self, text:str):
        # Hasil autocorrect
        new_tokens = []

        # Hubungin kata yang satu dengan yang lain
        tokens = word_tokenize(text)
        ngram_tokens = list(ngrams(tokens, self.n_gram, pad_left=True, left_pad_symbol = "<s>"))
        # Bikin list of list biar bisa dimutate
        ngram_tokens = [list(l) for l in ngram_tokens]

        # Jalanin
        for t in ngram_tokens:
            result = self.prob_grams(t)
            if len(result) == 0:
                new_tokens.append(t[-1])
            else:
                print(f"Corrected {t} to: ", end="")
                t[-1] = result.iloc[0]["word"][-1]
                new_tokens.append(t[-1])
                print(f"{t}")
        return TreebankWordDetokenizer().detokenize(new_tokens)

# %% [markdown]
# # Training
# Pake dataset reuters.

# %%
from nltk.corpus import reuters

# %%
text = reuters.raw()

# %%
print(f"Training using {len(word_tokenize(text))} tokens")
text[:200]
# Out:
# Training using 1548214 tokens
# "ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n  Mounting trade friction between the\n  U.S. And Japan has raised fears among many of Asia's exporting\n  nations that the row could inflict far-reachin"

# %%
unigram = ngram_checker(text, 1)
bigram = ngram_checker(text, 2)
trigram = ngram_checker(text, 3)
fourgram = ngram_checker(text, 4)

# %%
print(f"Unigram length: {len(unigram.word_freq)}")
display(unigram.word_freq.sort_values("freq", ascending=False).head(3))
print(f"Bigram length: {len(bigram.word_freq)}")
display(bigram.word_freq.sort_values("freq", ascending=False).head(3))
print(f"Trigram length: {len(trigram.word_freq)}")
display(trigram.word_freq.sort_values("freq", ascending=False).head(3))
print(f"Fourgram length: {len(fourgram.word_freq)}")
display(fourgram.word_freq.sort_values("freq", ascending=False).head(3))
# Out:
# Unigram length: 63318
#       word   freq
# 11  (the,)  58220
# 32    (,,)  53665
# 37    (.,)  50901
# Bigram length: 441155
#          word  freq
# 192   (lt, ;)  8694
# 191   (&, lt)  8694
# 91   (., The)  8635
# Trigram length: 929652
#                word  freq
# 198      (&, lt, ;)  8694
# 570  (said, ., The)  1516
# 569   (he, said, .)  1230
# Fourgram length: 1216597
#                           word  freq
# 13162          (INC, &, lt, ;)  1059
# 586          (,, '', he, said)   734
# 3552   (., The, company, said)   732

# %% [markdown]
# # Testing

# %% [markdown]
# ## Simple sentences

# %%
typo_string = "at the end otf"
tokens = word_tokenize(typo_string)

display(unigram.prob_grams(tokens).head(5))
display(bigram.prob_grams(tokens).head(5))
display(trigram.prob_grams(tokens).head(5))
display(fourgram.prob_grams(tokens).head(5))
# Out:
#       word   freq
# 20   (of,)  35949
# 53   (to,)  33981
# 76   (it,)   8834
# 135  (lt,)   8694
# 55   (on,)   8412
#              word freq
# 2646    (end, of)  548
# 20261   (end, to)   25
# 40318   (end, on)    7
# 76003  (end, its)    3
# 37935   (end, at)    3
#                 word freq
# 3067  (the, end, of)  501
#                     word freq
# 3166  (at, the, end, of)  250

# %% [markdown]
# ## Long texts

# %%
f = open("test.txt")
test = f.read()
f.close()
test
# Out:
# 'In a groundbreaking study, researchers at the renowned Lfie Sciences Institute have made a significant btreakthrough in the field of medical traeatment, offering new hope for patietns around the world. The study, led by Dr. Alexnder Johnson, focused on developing a novev therapy for neurologiucal disorders, particularly Alzheimer\'s diseaese.\n\nThe results of the study were publisehd today in the prestiogious jorunal, Science Advances, sending ripples of excitement thourghout the meducal community. The research team, comprizing experts from various diciplines, employed a combinatuion of gene therapy and stem cell research to develop a proimising new approach.\n\nDr. Johnson expalined, "Our study focused on enhancing neuronal regneration by tarhgting specific genetic markeers associated with neurodegenerative conditins. We utlilized advanced CRISPR techbology to modify and activate these markees, which ultimately led to a signifcant improement in cognitive functions in our animal models."\n\nWhile the results are only preliminary, the implications for human patiens are excting. If further researc and clinical triasl prove successful, this new treatment could revolutionize the way we apprach neurodegenerative disoreders and offer a ray of hope for the millions of people affected by these conditions worldwide.\n\nHowever, as with any scientific discvoery, it is imporant to approach these findings with cautin. The road to clinical applicatoin can be long and challanging, and many promsiing therapies fail to trnslate into effective treatments for human patiens. Additoinally, the studt was condcuted on animal mdoels, and it\'s unkown how the same theraetical advances will impact human bioilogy.\n\nThe research paper has already spawnded inetrnaitonal discussions among experts, with some expressing cautioon and a need for further studies to validate the findings. Dr. Sarah Thomposon, a prominnet neuroscientist at the Univeristy of Cambridge, saod, "While this study shos exciting potential, we need to be mindful of the complxity of neurodegenerative diseases. It\'s imporant to remmeber that many promsiing treaatments in the past have fallen shrt when trnslated into human clinical triasl."\n\nThe medical comunity is eagerly awiating further devlopments in this fieild. Organizations and philantropists have already srtated offering funding for additinal research to validate and refine the new therapy. Dr. Johnson and his team are plannig to beging humna trials in the near future, with the hopse of demonsrating the efficcy and safety of the treatment in actural patinets.\n\nIt\'s worth mentioning that tpos and errors do occu in scientific literature, espeically in the preliminary stages of resaerch. Peer review and repatition of the stud are crucal to identifyng and rectifying these isues. Typographical erorrs in particular can arise due to the hasty naure of publising results and the complexities of the scietific jargon invovled.\n\nDespite the typos and uncertainties surroinding this study, the scientific comunity remains optimistic about the potential of this novel treatment. Further researhc and colaboration are needed to fully unrderstand the mechanims\n'

# %%
unigram_res = unigram.autocorrect(test)
# Out:
# Corrected ['renowned'] to: ['renewed']
# Corrected ['Lfie'] to: ['five']
# Corrected ['btreakthrough'] to: ['breakthrough']
# Corrected ['traeatment'] to: ['treatment']
# Corrected ['patietns'] to: ['patents']
# Corrected ['Alexnder'] to: ['lender']
# Corrected ['novev'] to: ['over']
# Corrected ['diseaese'] to: ['disease']
# Corrected ['publisehd'] to: ['published']
# Corrected ['jorunal'] to: ['journal']
# Corrected ['Advances'] to: ['advance']
# Corrected ['ripples'] to: ['apples']
# Corrected ['thourghout'] to: ['throughout']
# Corrected ['meducal'] to: ['medical']
# Corrected ['comprizing'] to: ['comprising']
# Corrected ['diciplines'] to: ['discipline']
# Corrected ['combinatuion'] to: ['combination']
# Corrected ['gene'] to: ['were']
# Corrected ['proimising'] to: ['promising']
# Corrected ['expalined'] to: ['explained']
# Corrected ['regneration'] to: ['generation']
# Corrected ['tarhgting'] to: ['targeting']
# Corrected ['markeers'] to: ['markets']
# Corrected ['conditins'] to: ['conditions']
# Corrected ['utlilized'] to: ['utilized']
# Corrected ['techbology'] to: ['technology']
# Corrected ['markees'] to: ['market']
# Corrected ['signifcant'] to: ['significant']
# Corrected ['improement'] to: ['improvement']
# Corrected ['patiens'] to: ['nations']
# Corrected ['excting'] to: ['existing']
# Corrected ['researc'] to: ['research']
# Corrected ['triasl'] to: ['trial']
# Corrected ['apprach'] to: ['approach']
# Corrected ['disoreders'] to: ['disorders']
# Corrected ['ray'] to: ['a']
# Corrected ['discvoery'] to: ['discovery']
# Corrected ['imporant'] to: ['import']
# Corrected ['cautin'] to: ['causing']
# Corrected ['applicatoin'] to: ['application']
# Corrected ['challanging'] to: ['challenging']
# Corrected ['promsiing'] to: ['promising']
# Corrected ['trnslate'] to: ['translated']
# Corrected ['patiens'] to: ['nations']
# Corrected ['Additoinally'] to: ['Additionally']
# Corrected ['studt'] to: ['start']
# Corrected ['condcuted'] to: ['conducted']
# Corrected ['mdoels'] to: ['does']
# Corrected ['unkown'] to: ['union']
# Corrected ['theraetical'] to: ['theoretical']
# Corrected ['spawnded'] to: ['spawned']
# Corrected ['inetrnaitonal'] to: ['international']
# Corrected ['cautioon'] to: ['cautious']
# Corrected ['validate'] to: ['invalidate']
# Corrected ['Sarah'] to: ['march']
# Corrected ['Thomposon'] to: ['Thomson']
# Corrected ['prominnet'] to: ['prominent']
# Corrected ['Univeristy'] to: ['University']
# Corrected ['saod'] to: ['said']
# Corrected ['shos'] to: ['has']
# Corrected ['complxity'] to: ['complexity']
# Corrected ['imporant'] to: ['import']
# Corrected ['remmeber'] to: ['remember']
# Corrected ['promsiing'] to: ['promising']
# Corrected ['treaatments'] to: ['treatment']
# Corrected ['shrt'] to: ['that']
# Corrected ['trnslated'] to: ['translated']
# Corrected ['triasl'] to: ['trial']
# Corrected ['comunity'] to: ['community']
# Corrected ['eagerly'] to: ['early']
# Corrected ['awiating'] to: ['waiting']
# Corrected ['devlopments'] to: ['development']
# Corrected ['fieild'] to: ['field']
# Corrected ['srtated'] to: ['state']
# Corrected ['additinal'] to: ['additional']
# Corrected ['validate'] to: ['invalidate']
# Corrected ['plannig'] to: ['planned']
# Corrected ['beging'] to: ['being']
# Corrected ['humna'] to: ['human']
# Corrected ['hopse'] to: ['rose']
# Corrected ['demonsrating'] to: ['demonstrating']
# Corrected ['efficcy'] to: ['efficacy']
# Corrected ['actural'] to: ['natural']
# Corrected ['patinets'] to: ['patents']
# Corrected ['tpos'] to: ['to']
# Corrected ['occu'] to: ['once']
# Corrected ['espeically'] to: ['especially']
# Corrected ['resaerch'] to: ['research']
# Corrected ['Peer'] to: ['year']
# Corrected ['repatition'] to: ['reputation']
# Corrected ['stud'] to: ['said']
# Corrected ['crucal'] to: ['crucial']
# Corrected ['identifyng'] to: ['identify']
# Corrected ['rectifying'] to: ['testifying']
# Corrected ['isues'] to: ['issue']
# Corrected ['erorrs'] to: ['error']
# Corrected ['naure'] to: ['are']
# Corrected ['publising'] to: ['publishing']
# Corrected ['scietific'] to: ['scientific']
# Corrected ['invovled'] to: ['involved']
# Corrected ['typos'] to: ['type']
# Corrected ['surroinding'] to: ['surrounding']
# Corrected ['comunity'] to: ['community']
# Corrected ['researhc'] to: ['research']
# Corrected ['colaboration'] to: ['elaboration']
# Corrected ['unrderstand'] to: ['understand']
# Corrected ['mechanims'] to: ['mechanism']

# %%
bigram_res = bigram.autocorrect(test)
# Out:
# Corrected ['the', 'renowned'] to: ['the', 'renewed']
# Corrected ['for', 'patietns'] to: ['for', 'patents']
# Corrected ['a', 'novev'] to: ['a', 'move']
# Corrected ['the', 'meducal'] to: ['the', 'medical']
# Corrected [',', 'comprizing'] to: [',', 'comprising']
# Corrected ['a', 'combinatuion'] to: ['a', 'combination']
# Corrected ['of', 'gene'] to: ['of', 'one']
# Corrected ['a', 'proimising'] to: ['a', 'promising']
# Corrected ['these', 'markees'] to: ['these', 'markets']
# Corrected ['a', 'signifcant'] to: ['a', 'significant']
# Corrected ['are', 'excting'] to: ['are', 'acting']
# Corrected ['further', 'researc'] to: ['further', 'research']
# Corrected ['clinical', 'triasl'] to: ['clinical', 'trials']
# Corrected ['a', 'ray'] to: ['a', 'day']
# Corrected ['is', 'imporant'] to: ['is', 'important']
# Corrected ['with', 'cautin'] to: ['with', 'caution']
# Corrected ['to', 'trnslate'] to: ['to', 'translate']
# Corrected ['.', 'Additoinally'] to: ['.', 'Additionally']
# Corrected ['the', 'studt'] to: ['the', 'start']
# Corrected ['was', 'condcuted'] to: ['was', 'conducted']
# Corrected ["'s", 'unkown'] to: ["'s", 'known']
# Corrected ['to', 'validate'] to: ['to', 'invalidate']
# Corrected ['a', 'prominnet'] to: ['a', 'prominent']
# Corrected ['the', 'Univeristy'] to: ['the', 'University']
# Corrected [',', 'saod'] to: [',', 'and']
# Corrected ['study', 'shos'] to: ['study', 'has']
# Corrected ["'s", 'imporant'] to: ["'s", 'import']
# Corrected ['clinical', 'triasl'] to: ['clinical', 'trials']
# Corrected ['further', 'devlopments'] to: ['further', 'development']
# Corrected ['already', 'srtated'] to: ['already', 'started']
# Corrected ['for', 'additinal'] to: ['for', 'additional']
# Corrected ['to', 'validate'] to: ['to', 'invalidate']
# Corrected ['are', 'plannig'] to: ['are', 'planned']
# Corrected ['to', 'beging'] to: ['to', 'bring']
# Corrected ['the', 'hopse'] to: ['the', 'hope']
# Corrected ['the', 'efficcy'] to: ['the', 'efficacy']
# Corrected ['in', 'actural'] to: ['in', 'natural']
# Corrected ['that', 'tpos'] to: ['that', 'this']
# Corrected [',', 'espeically'] to: [',', 'especially']
# Corrected ['of', 'resaerch'] to: ['of', 'research']
# Corrected ['.', 'Peer'] to: ['.', 'Peter']
# Corrected ['the', 'stud'] to: ['the', 'study']
# Corrected ['are', 'crucal'] to: ['are', 'crucial']
# Corrected ['to', 'identifyng'] to: ['to', 'identify']
# Corrected ['these', 'isues'] to: ['these', 'issues']
# Corrected ['of', 'publising'] to: ['of', 'publishing']
# Corrected ['the', 'scietific'] to: ['the', 'scientific']
# Corrected ['the', 'typos'] to: ['the', 'type']
# Corrected ['uncertainties', 'surroinding'] to: ['uncertainties', 'surrounding']
# Corrected ['fully', 'unrderstand'] to: ['fully', 'understand']
# Corrected ['the', 'mechanims'] to: ['the', 'mechanism']

# %%
trigram_res = trigram.autocorrect(test)
# Out:
# Corrected ['to', 'a', 'signifcant'] to: ['to', 'a', 'significant']
# Corrected ['it', 'is', 'imporant'] to: ['it', 'is', 'important']
# Corrected [',', 'the', 'studt'] to: [',', 'the', 'start']
# Corrected [',', 'a', 'prominnet'] to: [',', 'a', 'prominent']
# Corrected ['at', 'the', 'Univeristy'] to: ['at', 'the', 'University']
# Corrected ['have', 'already', 'srtated'] to: ['have', 'already', 'started']
# Corrected ['of', 'the', 'stud'] to: ['of', 'the', 'study']
# Corrected ['of', 'the', 'scietific'] to: ['of', 'the', 'scientific']

# %%
fourgram_res = fourgram.autocorrect(test)
# Out:
# Corrected ['led', 'to', 'a', 'signifcant'] to: ['led', 'to', 'a', 'significant']
# Corrected [',', 'it', 'is', 'imporant'] to: [',', 'it', 'is', 'important']

# %%
# Kalo trigram ketemu, pake punya trigram, kalo gak pake punya bigram, kalo ga unigram.
class fallback_ngram:
    def __init__(self, models):
        self.models = models


    def autocorrect(self, text:str):
        new_tokens = []

        # Hubungin kata yang satu dengan yang lain
        tokens = word_tokenize(text)
        ngram_tokens = list(ngrams(tokens, 3, pad_left=True, left_pad_symbol = "<s>"))
        # Bikin list of list biar bisa dimutate
        ngram_tokens = [list(l) for l in ngram_tokens]

        # Jalanin
        for t in ngram_tokens:
            found = False
            for model in self.models:
                t = t[-model.n_gram:]
                result = model.prob_grams(t)
                if len(result):
                    print(f"Corrected {t} to: ", end="")
                    t[-1] = result.iloc[0]["word"][-1]
                    new_tokens.append(t[-1])
                    print(f"{t} ({model.n_gram}-gram)")
                    found = True
                    break
            if not found:
                new_tokens.append(t[-1])
        return TreebankWordDetokenizer().detokenize(new_tokens)

# %%
combined_model = fallback_ngram([fourgram, trigram, bigram, unigram])
combined_res = combined_model.autocorrect(test)
# Out:
# Corrected ['the', 'renowned'] to: ['the', 'renewed'] (2-gram)
# Corrected ['Lfie'] to: ['five'] (1-gram)
# Corrected ['btreakthrough'] to: ['breakthrough'] (1-gram)
# Corrected ['traeatment'] to: ['treatment'] (1-gram)
# Corrected ['for', 'patietns'] to: ['for', 'patents'] (2-gram)
# Corrected ['Alexnder'] to: ['lender'] (1-gram)
# Corrected ['a', 'novev'] to: ['a', 'move'] (2-gram)
# Corrected ['diseaese'] to: ['disease'] (1-gram)
# Corrected ['publisehd'] to: ['published'] (1-gram)
# Corrected ['jorunal'] to: ['journal'] (1-gram)
# Corrected ['Advances'] to: ['advance'] (1-gram)
# Corrected ['ripples'] to: ['apples'] (1-gram)
# Corrected ['thourghout'] to: ['throughout'] (1-gram)
# Corrected ['the', 'meducal'] to: ['the', 'medical'] (2-gram)
# Corrected [',', 'comprizing'] to: [',', 'comprising'] (2-gram)
# Corrected ['diciplines'] to: ['discipline'] (1-gram)
# Corrected ['a', 'combinatuion'] to: ['a', 'combination'] (2-gram)
# Corrected ['of', 'gene'] to: ['of', 'one'] (2-gram)
# Corrected ['a', 'proimising'] to: ['a', 'promising'] (2-gram)
# Corrected ['expalined'] to: ['explained'] (1-gram)
# Corrected ['regneration'] to: ['generation'] (1-gram)
# Corrected ['tarhgting'] to: ['targeting'] (1-gram)
# Corrected ['markeers'] to: ['markets'] (1-gram)
# Corrected ['conditins'] to: ['conditions'] (1-gram)
# Corrected ['utlilized'] to: ['utilized'] (1-gram)
# Corrected ['techbology'] to: ['technology'] (1-gram)
# Corrected ['these', 'markees'] to: ['these', 'markets'] (2-gram)
# Corrected ['to', 'a', 'signifcant'] to: ['to', 'a', 'significant'] (3-gram)
# Corrected ['improement'] to: ['improvement'] (1-gram)
# Corrected ['patiens'] to: ['nations'] (1-gram)
# Corrected ['are', 'excting'] to: ['are', 'acting'] (2-gram)
# Corrected ['further', 'researc'] to: ['further', 'research'] (2-gram)
# Corrected ['clinical', 'triasl'] to: ['clinical', 'trials'] (2-gram)
# Corrected ['apprach'] to: ['approach'] (1-gram)
# Corrected ['disoreders'] to: ['disorders'] (1-gram)
# Corrected ['a', 'ray'] to: ['a', 'day'] (2-gram)
# Corrected ['discvoery'] to: ['discovery'] (1-gram)
# Corrected ['it', 'is', 'imporant'] to: ['it', 'is', 'important'] (3-gram)
# Corrected ['with', 'cautin'] to: ['with', 'caution'] (2-gram)
# Corrected ['applicatoin'] to: ['application'] (1-gram)
# Corrected ['challanging'] to: ['challenging'] (1-gram)
# Corrected ['promsiing'] to: ['promising'] (1-gram)
# Corrected ['to', 'trnslate'] to: ['to', 'translate'] (2-gram)
# Corrected ['patiens'] to: ['nations'] (1-gram)
# Corrected ['.', 'Additoinally'] to: ['.', 'Additionally'] (2-gram)
# Corrected [',', 'the', 'studt'] to: [',', 'the', 'start'] (3-gram)
# Corrected ['was', 'condcuted'] to: ['was', 'conducted'] (2-gram)
# Corrected ['mdoels'] to: ['does'] (1-gram)
# Corrected ["'s", 'unkown'] to: ["'s", 'known'] (2-gram)
# Corrected ['theraetical'] to: ['theoretical'] (1-gram)
# Corrected ['spawnded'] to: ['spawned'] (1-gram)
# Corrected ['inetrnaitonal'] to: ['international'] (1-gram)
# Corrected ['cautioon'] to: ['cautious'] (1-gram)
# Corrected ['to', 'validate'] to: ['to', 'invalidate'] (2-gram)
# Corrected ['Sarah'] to: ['march'] (1-gram)
# Corrected ['Thomposon'] to: ['Thomson'] (1-gram)
# Corrected [',', 'a', 'prominnet'] to: [',', 'a', 'prominent'] (3-gram)
# Corrected ['at', 'the', 'Univeristy'] to: ['at', 'the', 'University'] (3-gram)
# Corrected [',', 'saod'] to: [',', 'and'] (2-gram)
# Corrected ['study', 'shos'] to: ['study', 'has'] (2-gram)
# Corrected ['complxity'] to: ['complexity'] (1-gram)
# Corrected ["'s", 'imporant'] to: ["'s", 'import'] (2-gram)
# Corrected ['remmeber'] to: ['remember'] (1-gram)
# Corrected ['promsiing'] to: ['promising'] (1-gram)
# Corrected ['treaatments'] to: ['treatment'] (1-gram)
# Corrected ['shrt'] to: ['that'] (1-gram)
# Corrected ['trnslated'] to: ['translated'] (1-gram)
# Corrected ['clinical', 'triasl'] to: ['clinical', 'trials'] (2-gram)
# Corrected ['comunity'] to: ['community'] (1-gram)
# Corrected ['eagerly'] to: ['early'] (1-gram)
# Corrected ['awiating'] to: ['waiting'] (1-gram)
# Corrected ['further', 'devlopments'] to: ['further', 'development'] (2-gram)
# Corrected ['fieild'] to: ['field'] (1-gram)
# Corrected ['have', 'already', 'srtated'] to: ['have', 'already', 'started'] (3-gram)
# Corrected ['for', 'additinal'] to: ['for', 'additional'] (2-gram)
# Corrected ['to', 'validate'] to: ['to', 'invalidate'] (2-gram)
# Corrected ['are', 'plannig'] to: ['are', 'planned'] (2-gram)
# Corrected ['to', 'beging'] to: ['to', 'bring'] (2-gram)
# Corrected ['humna'] to: ['human'] (1-gram)
# Corrected ['the', 'hopse'] to: ['the', 'hope'] (2-gram)
# Corrected ['demonsrating'] to: ['demonstrating'] (1-gram)
# Corrected ['the', 'efficcy'] to: ['the', 'efficacy'] (2-gram)
# Corrected ['in', 'actural'] to: ['in', 'natural'] (2-gram)
# Corrected ['patinets'] to: ['patents'] (1-gram)
# Corrected ['that', 'tpos'] to: ['that', 'this'] (2-gram)
# Corrected ['occu'] to: ['once'] (1-gram)
# Corrected [',', 'espeically'] to: [',', 'especially'] (2-gram)
# Corrected ['of', 'resaerch'] to: ['of', 'research'] (2-gram)
# Corrected ['.', 'Peer'] to: ['.', 'Peter'] (2-gram)
# Corrected ['repatition'] to: ['reputation'] (1-gram)
# Corrected ['of', 'the', 'stud'] to: ['of', 'the', 'study'] (3-gram)
# Corrected ['are', 'crucal'] to: ['are', 'crucial'] (2-gram)
# Corrected ['to', 'identifyng'] to: ['to', 'identify'] (2-gram)
# Corrected ['rectifying'] to: ['testifying'] (1-gram)
# Corrected ['these', 'isues'] to: ['these', 'issues'] (2-gram)
# Corrected ['erorrs'] to: ['error'] (1-gram)
# Corrected ['naure'] to: ['are'] (1-gram)
# Corrected ['of', 'publising'] to: ['of', 'publishing'] (2-gram)
# Corrected ['of', 'the', 'scietific'] to: ['of', 'the', 'scientific'] (3-gram)
# Corrected ['invovled'] to: ['involved'] (1-gram)
# Corrected ['the', 'typos'] to: ['the', 'type'] (2-gram)
# Corrected ['uncertainties', 'surroinding'] to: ['uncertainties', 'surrounding'] (2-gram)
# Corrected ['comunity'] to: ['community'] (1-gram)
# Corrected ['researhc'] to: ['research'] (1-gram)
# Corrected ['colaboration'] to: ['elaboration'] (1-gram)
# Corrected ['fully', 'unrderstand'] to: ['fully', 'understand'] (2-gram)
# Corrected ['the', 'mechanims'] to: ['the', 'mechanism'] (2-gram)

# %%
combined_model2 = fallback_ngram([bigram, unigram])
combined_res2 = combined_model2.autocorrect(test)
# Out:
# Corrected ['the', 'renowned'] to: ['the', 'renewed'] (2-gram)
# Corrected ['Lfie'] to: ['five'] (1-gram)
# Corrected ['btreakthrough'] to: ['breakthrough'] (1-gram)
# Corrected ['traeatment'] to: ['treatment'] (1-gram)
# Corrected ['for', 'patietns'] to: ['for', 'patents'] (2-gram)
# Corrected ['Alexnder'] to: ['lender'] (1-gram)
# Corrected ['a', 'novev'] to: ['a', 'move'] (2-gram)
# Corrected ['diseaese'] to: ['disease'] (1-gram)
# Corrected ['publisehd'] to: ['published'] (1-gram)
# Corrected ['jorunal'] to: ['journal'] (1-gram)
# Corrected ['Advances'] to: ['advance'] (1-gram)
# Corrected ['ripples'] to: ['apples'] (1-gram)
# Corrected ['thourghout'] to: ['throughout'] (1-gram)
# Corrected ['the', 'meducal'] to: ['the', 'medical'] (2-gram)
# Corrected [',', 'comprizing'] to: [',', 'comprising'] (2-gram)
# Corrected ['diciplines'] to: ['discipline'] (1-gram)
# Corrected ['a', 'combinatuion'] to: ['a', 'combination'] (2-gram)
# Corrected ['of', 'gene'] to: ['of', 'one'] (2-gram)
# Corrected ['a', 'proimising'] to: ['a', 'promising'] (2-gram)
# Corrected ['expalined'] to: ['explained'] (1-gram)
# Corrected ['regneration'] to: ['generation'] (1-gram)
# Corrected ['tarhgting'] to: ['targeting'] (1-gram)
# Corrected ['markeers'] to: ['markets'] (1-gram)
# Corrected ['conditins'] to: ['conditions'] (1-gram)
# Corrected ['utlilized'] to: ['utilized'] (1-gram)
# Corrected ['techbology'] to: ['technology'] (1-gram)
# Corrected ['these', 'markees'] to: ['these', 'markets'] (2-gram)
# Corrected ['a', 'signifcant'] to: ['a', 'significant'] (2-gram)
# Corrected ['improement'] to: ['improvement'] (1-gram)
# Corrected ['patiens'] to: ['nations'] (1-gram)
# Corrected ['are', 'excting'] to: ['are', 'acting'] (2-gram)
# Corrected ['further', 'researc'] to: ['further', 'research'] (2-gram)
# Corrected ['clinical', 'triasl'] to: ['clinical', 'trials'] (2-gram)
# Corrected ['apprach'] to: ['approach'] (1-gram)
# Corrected ['disoreders'] to: ['disorders'] (1-gram)
# Corrected ['a', 'ray'] to: ['a', 'day'] (2-gram)
# Corrected ['discvoery'] to: ['discovery'] (1-gram)
# Corrected ['is', 'imporant'] to: ['is', 'important'] (2-gram)
# Corrected ['with', 'cautin'] to: ['with', 'caution'] (2-gram)
# Corrected ['applicatoin'] to: ['application'] (1-gram)
# Corrected ['challanging'] to: ['challenging'] (1-gram)
# Corrected ['promsiing'] to: ['promising'] (1-gram)
# Corrected ['to', 'trnslate'] to: ['to', 'translate'] (2-gram)
# Corrected ['patiens'] to: ['nations'] (1-gram)
# Corrected ['.', 'Additoinally'] to: ['.', 'Additionally'] (2-gram)
# Corrected ['the', 'studt'] to: ['the', 'start'] (2-gram)
# Corrected ['was', 'condcuted'] to: ['was', 'conducted'] (2-gram)
# Corrected ['mdoels'] to: ['does'] (1-gram)
# Corrected ["'s", 'unkown'] to: ["'s", 'known'] (2-gram)
# Corrected ['theraetical'] to: ['theoretical'] (1-gram)
# Corrected ['spawnded'] to: ['spawned'] (1-gram)
# Corrected ['inetrnaitonal'] to: ['international'] (1-gram)
# Corrected ['cautioon'] to: ['cautious'] (1-gram)
# Corrected ['to', 'validate'] to: ['to', 'invalidate'] (2-gram)
# Corrected ['Sarah'] to: ['march'] (1-gram)
# Corrected ['Thomposon'] to: ['Thomson'] (1-gram)
# Corrected ['a', 'prominnet'] to: ['a', 'prominent'] (2-gram)
# Corrected ['the', 'Univeristy'] to: ['the', 'University'] (2-gram)
# Corrected [',', 'saod'] to: [',', 'and'] (2-gram)
# Corrected ['study', 'shos'] to: ['study', 'has'] (2-gram)
# Corrected ['complxity'] to: ['complexity'] (1-gram)
# Corrected ["'s", 'imporant'] to: ["'s", 'import'] (2-gram)
# Corrected ['remmeber'] to: ['remember'] (1-gram)
# Corrected ['promsiing'] to: ['promising'] (1-gram)
# Corrected ['treaatments'] to: ['treatment'] (1-gram)
# Corrected ['shrt'] to: ['that'] (1-gram)
# Corrected ['trnslated'] to: ['translated'] (1-gram)
# Corrected ['clinical', 'triasl'] to: ['clinical', 'trials'] (2-gram)
# Corrected ['comunity'] to: ['community'] (1-gram)
# Corrected ['eagerly'] to: ['early'] (1-gram)
# Corrected ['awiating'] to: ['waiting'] (1-gram)
# Corrected ['further', 'devlopments'] to: ['further', 'development'] (2-gram)
# Corrected ['fieild'] to: ['field'] (1-gram)
# Corrected ['already', 'srtated'] to: ['already', 'started'] (2-gram)
# Corrected ['for', 'additinal'] to: ['for', 'additional'] (2-gram)
# Corrected ['to', 'validate'] to: ['to', 'invalidate'] (2-gram)
# Corrected ['are', 'plannig'] to: ['are', 'planned'] (2-gram)
# Corrected ['to', 'beging'] to: ['to', 'bring'] (2-gram)
# Corrected ['humna'] to: ['human'] (1-gram)
# Corrected ['the', 'hopse'] to: ['the', 'hope'] (2-gram)
# Corrected ['demonsrating'] to: ['demonstrating'] (1-gram)
# Corrected ['the', 'efficcy'] to: ['the', 'efficacy'] (2-gram)
# Corrected ['in', 'actural'] to: ['in', 'natural'] (2-gram)
# Corrected ['patinets'] to: ['patents'] (1-gram)
# Corrected ['that', 'tpos'] to: ['that', 'this'] (2-gram)
# Corrected ['occu'] to: ['once'] (1-gram)
# Corrected [',', 'espeically'] to: [',', 'especially'] (2-gram)
# Corrected ['of', 'resaerch'] to: ['of', 'research'] (2-gram)
# Corrected ['.', 'Peer'] to: ['.', 'Peter'] (2-gram)
# Corrected ['repatition'] to: ['reputation'] (1-gram)
# Corrected ['the', 'stud'] to: ['the', 'study'] (2-gram)
# Corrected ['are', 'crucal'] to: ['are', 'crucial'] (2-gram)
# Corrected ['to', 'identifyng'] to: ['to', 'identify'] (2-gram)
# Corrected ['rectifying'] to: ['testifying'] (1-gram)
# Corrected ['these', 'isues'] to: ['these', 'issues'] (2-gram)
# Corrected ['erorrs'] to: ['error'] (1-gram)
# Corrected ['naure'] to: ['are'] (1-gram)
# Corrected ['of', 'publising'] to: ['of', 'publishing'] (2-gram)
# Corrected ['the', 'scietific'] to: ['the', 'scientific'] (2-gram)
# Corrected ['invovled'] to: ['involved'] (1-gram)
# Corrected ['the', 'typos'] to: ['the', 'type'] (2-gram)
# Corrected ['uncertainties', 'surroinding'] to: ['uncertainties', 'surrounding'] (2-gram)
# Corrected ['comunity'] to: ['community'] (1-gram)
# Corrected ['researhc'] to: ['research'] (1-gram)
# Corrected ['colaboration'] to: ['elaboration'] (1-gram)
# Corrected ['fully', 'unrderstand'] to: ['fully', 'understand'] (2-gram)
# Corrected ['the', 'mechanims'] to: ['the', 'mechanism'] (2-gram)

# %% [markdown]
# # Evaluation

# %%
f = open("answer.txt")
ans = f.read()
f.close()
ans_token = word_tokenize(ans)

# %%
for result, name in [(test, "Original Text"), (unigram_res, "Unigram"), (bigram_res, "Bigram"), (trigram_res, "Trigram"), (fourgram_res, "Fourgram"), (combined_res, "1-4 Gram"), (combined_res2, "1-2 Gram")]:
    tokens = word_tokenize(result)
    mistakes = sum([a == b for (a, b) in zip(tokens, ans_token)])
    print(f"Correctly spelt words for {name} is {mistakes} / {len(tokens)}. {mistakes/len(tokens)}")

# %% [markdown]
# # Buat Screenshot PPT

# %%
print("renowned")
display(unigram.word_freq[unigram.word_freq["word"] == tuple(["renowned"])])
print("\n\nrenewed")
display(unigram.word_freq[unigram.word_freq["word"] == tuple(["renewed"])])

# %%
bigram = ngram_checker(text, 2)

# %%
bigram_test = bigram.word_freq
bigram_test["word1"] = bigram_test["word"].apply(lambda x: x[0])
bigram_test["word2"] = bigram_test["word"].apply(lambda x: x[1])
bigram_test = bigram_test.drop("word", axis=1)
words =["for", "the", "vs"]
bigram_test = bigram_test[bigram_test["word1"].isin(words) & bigram_test["word2"].isin(words)]
display(bigram_test)
display(bigram_test.pivot_table(values="freq", index="word1", columns="word2", fill_value=0))

# %%
combined_res2
